# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_name = "CostManagement_marsaazplan_rtm_2023-04-13-1226.xlsx"
data_df = pd.read_excel(file_name, sheet_name="Data")
data_df = data_df[['UsageDate', "ServiceName", "CostUSD"]]

# %%
data_df.head(25)
# Out:
#      UsageDate               ServiceName     CostUSD
# 0   2022-10-01         Azure App Service  669.600000
# 1   2022-10-01  Azure Kubernetes Service   80.743645
# 2   2022-10-01             Azure Monitor    0.905095
# 3   2022-10-01                 Bandwidth    1.977248
# 4   2022-10-01                Event Hubs   22.320018
# 5   2022-10-01             Load Balancer   32.147545
# 6   2022-10-01             Log Analytics  122.220979
# 7   2022-10-01           Network Watcher    0.001000
# 8   2022-10-01               Service Bus    0.000600
# 9   2022-10-01                   Storage  865.042170
# 10  2022-10-01          Virtual Machines  112.633615
# 11  2022-10-01           Virtual Network   14.813396
# 12  2022-11-01         Azure App Service  648.000000
# 13  2022-11-01  Azure Kubernetes Service   71.997071
# 14  2022-11-01             Azure Monitor    1.085617
# 15  2022-11-01                 Bandwidth    2.100102
# 16  2022-11-01                Event Hubs   21.600013
# 17  2022-11-01             Load Balancer   20.312558
# 18  2022-11-01             Log Analytics  126.273745
# 19  2022-11-01               Service Bus    0.000576
# 20  2022-11-01                   Storage  887.181272
# 21  2022-11-01          Virtual Machines    0.000000
# 22  2022-11-01           Virtual Network   13.391994
# 23  2022-12-01         Azure App Service  669.600000
# 24  2022-12-01  Azure Kubernetes Service   74.387951

# %%
date_list_to_remove = ['2022-10-01', '2022-11-01'] 
for date in date_list_to_remove:
    data_df = data_df[data_df.UsageDate != date]

# %%
data_df.reset_index()
# Out:
#     index   UsageDate               ServiceName     CostUSD
# 0      23  2022-12-01         Azure App Service  669.600000
# 1      24  2022-12-01  Azure Kubernetes Service   74.387951
# 2      25  2022-12-01             Azure Monitor    1.398522
# 3      26  2022-12-01                 Bandwidth    2.202458
# 4      27  2022-12-01                Event Hubs   22.320007
# 5      28  2022-12-01             Load Balancer   20.925580
# 6      29  2022-12-01             Log Analytics  123.887243
# 7      30  2022-12-01               Service Bus    0.000594
# 8      31  2022-12-01                   Storage  958.386417
# 9      32  2022-12-01          Virtual Machines    0.000000
# 10     33  2022-12-01           Virtual Network   13.838400
# 11     34  2023-01-01         Azure App Service  668.300000
# 12     35  2023-01-01  Azure Kubernetes Service   74.402057
# 13     36  2023-01-01             Azure Monitor    1.397984
# 14     37  2023-01-01                 Bandwidth    2.236786
# 15     38  2023-01-01                Event Hubs   22.320005
# 16     39  2023-01-01             Load Balancer   21.129161
# 17     40  2023-01-01             Log Analytics  123.196257
# 18     41  2023-01-01               Service Bus    0.000591
# 19     42  2023-01-01                   Storage  993.933550
# 20     43  2023-01-01          Virtual Machines    0.000000
# 21     44  2023-01-01           Virtual Network   13.838397
# 22     45  2023-02-01         Azure App Service  604.800000
# 23     46  2023-02-01  Azure Kubernetes Service   67.204555
# 24     47  2023-02-01             Azure Monitor    1.263306
# 25     48  2023-02-01                 Bandwidth    4.595296
# 26     49  2023-02-01                Event Hubs   20.160003
# 27     50  2023-02-01             Load Balancer   18.218459
# 28     51  2023-02-01             Log Analytics  110.500601
# 29     52  2023-02-01               Service Bus    0.000538
# 30     53  2023-02-01                   Storage  925.939338
# 31     54  2023-02-01          Virtual Machines    0.000000
# 32     55  2023-02-01           Virtual Network   12.499199
# 33     56  2023-03-01         Azure App Service  669.600000
# 34     57  2023-03-01  Azure Kubernetes Service   82.876639
# 35     58  2023-03-01             Azure Monitor    1.399731
# 36     59  2023-03-01                 Bandwidth    2.891120
# 37     60  2023-03-01                Event Hubs   22.320004
# 38     61  2023-03-01             Load Balancer   32.440122
# 39     62  2023-03-01             Log Analytics  123.234606
# 40     63  2023-03-01               Service Bus    0.000599
# 41     64  2023-03-01                   Storage  924.620123
# 42     65  2023-03-01          Virtual Machines  280.827883
# 43     66  2023-03-01           Virtual Network   20.661717

# %%
data_df['ServiceName'] = data_df['ServiceName'].str.replace('Azure Kubernetes Service','Azure Kubernetes')
data_df['ServiceName'] = data_df['ServiceName'].str.replace('Azure App Service','Azure Apps')

# %%
data_df["ServiceName"].head(len(data_df["ServiceName"].unique()))
# Out:
# 23          Azure Apps
# 24    Azure Kubernetes
# 25       Azure Monitor
# 26           Bandwidth
# 27          Event Hubs
# 28       Load Balancer
# 29       Log Analytics
# 30         Service Bus
# 31             Storage
# 32    Virtual Machines
# 33     Virtual Network
# Name: ServiceName, dtype: object

# %%
average_costs = data_df.groupby(['ServiceName'], as_index=False).mean()
average_costs
# Out:
#          ServiceName     CostUSD
# 0         Azure Apps  653.075000
# 1   Azure Kubernetes   74.717801
# 2      Azure Monitor    1.364886
# 3          Bandwidth    2.981415
# 4         Event Hubs   21.780005
# 5      Load Balancer   23.178330
# 6      Log Analytics  120.204676
# 7        Service Bus    0.000580
# 8            Storage  950.719857
# 9   Virtual Machines   70.206971
# 10   Virtual Network   15.209428

# %%
average_costs.columns
# Out:
# Index(['ServiceName', 'CostUSD'], dtype='object')

# %%
average_costs["Cost_by_percentage"] = average_costs["CostUSD"]/average_costs["CostUSD"].sum()*100
average_costs = average_costs.sort_values(by=['Cost_by_percentage'], ascending=False)
average_costs
# Out:
#          ServiceName     CostUSD  Cost_by_percentage
# 8            Storage  950.719857           49.172479
# 0         Azure Apps  653.075000           33.777896
# 6      Log Analytics  120.204676            6.217144
# 1   Azure Kubernetes   74.717801            3.864503
# 9   Virtual Machines   70.206971            3.631197
# 5      Load Balancer   23.178330            1.198814
# 4         Event Hubs   21.780005            1.126490
# 10   Virtual Network   15.209428            0.786652
# 3          Bandwidth    2.981415            0.154203
# 2      Azure Monitor    1.364886            0.070594
# 7        Service Bus    0.000580            0.000030

# %%
important_columns = average_costs[average_costs["Cost_by_percentage"] >2]
important_columns
# Out:
#         ServiceName     CostUSD  Cost_by_percentage
# 8           Storage  950.719857           49.172479
# 0        Azure Apps  653.075000           33.777896
# 6     Log Analytics  120.204676            6.217144
# 1  Azure Kubernetes   74.717801            3.864503
# 9  Virtual Machines   70.206971            3.631197

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(important_columns["ServiceName"], important_columns["CostUSD"])
plt.show()

# %%
list_of_services = list(average_costs["ServiceName"].unique())
list_of_services
# Out:
# ['Storage',
#  'Azure Apps',
#  'Log Analytics',
#  'Azure Kubernetes',
#  'Virtual Machines',
#  'Load Balancer',
#  'Event Hubs',
#  'Virtual Network',
#  'Bandwidth',
#  'Azure Monitor',
#  'Service Bus']

# %%
total_id_list = []
total_value_list = []

for service in list_of_services:
    test = data_df.loc[data_df['ServiceName'] == service]["CostUSD"]/int(average_costs.loc[average_costs['ServiceName'] == service]["CostUSD"])*100
    for index in test.index:
        total_id_list.append(index)
    for value in test:
        total_value_list.append(value)


index_value_dict = dict(zip(total_id_list, total_value_list))
keys_list = list(index_value_dict.keys())
keys_list.sort()
sorted_index_value_dict = {key: index_value_dict[key] for key in keys_list}
sorted_index_value_dict
# Out:
# {23: 102.54211332312404,
#  24: 100.52425779874636,
#  25: 139.8521505376345,
#  26: 110.12289136720872,
#  27: 106.28574748571428,
#  28: 90.9807822083771,
#  29: 103.23936897626649,
#  30: inf,
#  31: 100.88278069279998,
#  32: 0.0,
#  33: 92.256,
#  34: 102.34303215926492,
#  35: 100.54332080065254,
#  36: 139.7983870967743,
#  37: 111.83927887848961,
#  38: 106.2857360190476,
#  39: 91.86591627576348,
#  40: 102.6635473115879,
#  41: inf,
#  42: 104.62458425795789,
#  43: 0.0,
#  44: 92.25598148148148,
#  45: 92.61868300153142,
#  46: 90.81696630288072,
#  47: 126.3306451612903,
#  48: 229.76481327465837,
#  49: 96.00001320000004,
#  50: 79.21069104048304,
#  51: 92.08383376995033,
#  52: inf,
#  53: 97.4672987419579,
#  54: 0.0,
#  55: 83.32799074074076,
#  56: 102.54211332312408,
#  57: 111.99545781817054,
#  58: 139.97311827956986,
#  59: 144.55601759773114,
#  60: 106.28573521904767,
#  61: 141.04400866485435,
#  62: 102.69550460159773,
#  63: inf,
#  64: 97.3284339735579,
#  65: 401.18268973714305,
#  66: 137.7447777777778}

# %%
data_df['index_column'] = data_df.index

# %%
data_df['Percentage from the Average Cost'] = data_df['index_column'].map(sorted_index_value_dict)
data_df
# Out:
#      UsageDate       ServiceName     CostUSD  index_column  \
# 23  2022-12-01        Azure Apps  669.600000            23
# 24  2022-12-01  Azure Kubernetes   74.387951            24
# 25  2022-12-01     Azure Monitor    1.398522            25
# 26  2022-12-01         Bandwidth    2.202458            26
# 27  2022-12-01        Event Hubs   22.320007            27
# 28  2022-12-01     Load Balancer   20.925580            28
# 29  2022-12-01     Log Analytics  123.887243            29
# 30  2022-12-01       Service Bus    0.000594            30
# 31  2022-12-01           Storage  958.386417            31
# 32  2022-12-01  Virtual Machines    0.000000            32
# 33  2022-12-01   Virtual Network   13.838400            33
# 34  2023-01-01        Azure Apps  668.300000            34
# 35  2023-01-01  Azure Kubernetes   74.402057            35
# 36  2023-01-01     Azure Monitor    1.397984            36
# 37  2023-01-01         Bandwidth    2.236786            37
# 38  2023-01-01        Event Hubs   22.320005            38
# 39  2023-01-01     Load Balancer   21.129161            39
# 40  2023-01-01     Log Analytics  123.196257            40
# 41  2023-01-01       Service Bus    0.000591            41
# 42  2023-01-01           Storage  993.933550            42
# 43  2023-01-01  Virtual Machines    0.000000            43
# 44  2023-01-01   Virtual Network   13.838397            44
# 45  2023-02-01        Azure Apps  604.800000            45
# 46  2023-02-01  Azure Kubernetes   67.204555            46
# 47  2023-02-01     Azure Monitor    1.263306            47
# 48  2023-02-01         Bandwidth    4.595296            48
# 49  2023-02-01        Event Hubs   20.160003            49
# 50  2023-02-01     Load Balancer   18.218459            50
# 51  2023-02-01     Log Analytics  110.500601            51
# 52  2023-02-01       Service Bus    0.000538            52
# 53  2023-02-01           Storage  925.939338            53
# 54  2023-02-01  Virtual Machines    0.000000            54
# 55  2023-02-01   Virtual Network   12.499199            55
# 56  2023-03-01        Azure Apps  669.600000            56
# 57  2023-03-01  Azure Kubernetes   82.876639            57
# 58  2023-03-01     Azure Monitor    1.399731            58
# 59  2023-03-01         Bandwidth    2.891120            59
# 60  2023-03-01        Event Hubs   22.320004            60
# 61  2023-03-01     Load Balancer   32.440122            61
# 62  2023-03-01     Log Analytics  123.234606            62
# 63  2023-03-01       Service Bus    0.000599            63
# 64  2023-03-01           Storage  924.620123            64
# 65  2023-03-01  Virtual Machines  280.827883            65
# 66  2023-03-01   Virtual Network   20.661717            66
#
#     Percentage from the Average Cost
# 23                        102.542113
# 24                        100.524258
# 25                        139.852151
# 26                        110.122891
# 27                        106.285747
# 28                         90.980782
# 29                        103.239369
# 30                               inf
# 31                        100.882781
# 32                          0.000000
# 33                         92.256000
# 34                        102.343032
# 35                        100.543321
# 36                        139.798387
# 37                        111.839279
# 38                        106.285736
# 39                         91.865916
# 40                        102.663547
# 41                               inf
# 42                        104.624584
# 43                          0.000000
# 44                         92.255981
# 45                         92.618683
# 46                         90.816966
# 47                        126.330645
# 48                        229.764813
# 49                         96.000013
# 50                         79.210691
# 51                         92.083834
# 52                               inf
# 53                         97.467299
# 54                          0.000000
# 55                         83.327991
# 56                        102.542113
# 57                        111.995458
# 58                        139.973118
# 59                        144.556018
# 60                        106.285735
# 61                        141.044009
# 62                        102.695505
# 63                               inf
# 64                         97.328434
# 65                        401.182690
# 66                        137.744778

# %%
data_df.drop(['index_column'], axis=1, inplace=True)
data_df
# Out:
#      UsageDate       ServiceName     CostUSD  Percentage from the Average Cost
# 23  2022-12-01        Azure Apps  669.600000                        102.542113
# 24  2022-12-01  Azure Kubernetes   74.387951                        100.524258
# 25  2022-12-01     Azure Monitor    1.398522                        139.852151
# 26  2022-12-01         Bandwidth    2.202458                        110.122891
# 27  2022-12-01        Event Hubs   22.320007                        106.285747
# 28  2022-12-01     Load Balancer   20.925580                         90.980782
# 29  2022-12-01     Log Analytics  123.887243                        103.239369
# 30  2022-12-01       Service Bus    0.000594                               inf
# 31  2022-12-01           Storage  958.386417                        100.882781
# 32  2022-12-01  Virtual Machines    0.000000                          0.000000
# 33  2022-12-01   Virtual Network   13.838400                         92.256000
# 34  2023-01-01        Azure Apps  668.300000                        102.343032
# 35  2023-01-01  Azure Kubernetes   74.402057                        100.543321
# 36  2023-01-01     Azure Monitor    1.397984                        139.798387
# 37  2023-01-01         Bandwidth    2.236786                        111.839279
# 38  2023-01-01        Event Hubs   22.320005                        106.285736
# 39  2023-01-01     Load Balancer   21.129161                         91.865916
# 40  2023-01-01     Log Analytics  123.196257                        102.663547
# 41  2023-01-01       Service Bus    0.000591                               inf
# 42  2023-01-01           Storage  993.933550                        104.624584
# 43  2023-01-01  Virtual Machines    0.000000                          0.000000
# 44  2023-01-01   Virtual Network   13.838397                         92.255981
# 45  2023-02-01        Azure Apps  604.800000                         92.618683
# 46  2023-02-01  Azure Kubernetes   67.204555                         90.816966
# 47  2023-02-01     Azure Monitor    1.263306                        126.330645
# 48  2023-02-01         Bandwidth    4.595296                        229.764813
# 49  2023-02-01        Event Hubs   20.160003                         96.000013
# 50  2023-02-01     Load Balancer   18.218459                         79.210691
# 51  2023-02-01     Log Analytics  110.500601                         92.083834
# 52  2023-02-01       Service Bus    0.000538                               inf
# 53  2023-02-01           Storage  925.939338                         97.467299
# 54  2023-02-01  Virtual Machines    0.000000                          0.000000
# 55  2023-02-01   Virtual Network   12.499199                         83.327991
# 56  2023-03-01        Azure Apps  669.600000                        102.542113
# 57  2023-03-01  Azure Kubernetes   82.876639                        111.995458
# 58  2023-03-01     Azure Monitor    1.399731                        139.973118
# 59  2023-03-01         Bandwidth    2.891120                        144.556018
# 60  2023-03-01        Event Hubs   22.320004                        106.285735
# 61  2023-03-01     Load Balancer   32.440122                        141.044009
# 62  2023-03-01     Log Analytics  123.234606                        102.695505
# 63  2023-03-01       Service Bus    0.000599                               inf
# 64  2023-03-01           Storage  924.620123                         97.328434
# 65  2023-03-01  Virtual Machines  280.827883                        401.182690
# 66  2023-03-01   Virtual Network   20.661717                        137.744778

# %%
monthly_prices_df = data_df.groupby(['UsageDate'], as_index=False)['CostUSD'].sum()
data_df = data_df[data_df.UsageDate != date]
print(monthly_prices_df)
# Out:
#     UsageDate      CostUSD
# 0  2022-12-01  1886.947170
# 1  2023-01-01  1920.754788
# 2  2023-02-01  1765.181294
# 3  2023-03-01  2160.872544

# %%
monthly_prices_df['CostUSD'].mean()
# Out:
# 1933.4389489176779

# %%
monthly_prices_df['CostUSD'].sum()
# Out:
# 7733.755795670711

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(monthly_prices_df["UsageDate"], monthly_prices_df["CostUSD"])
plt.show()

# %%
data_df = data_df[data_df["CostUSD"] >60]

# %%
data_df
# Out:
#      UsageDate       ServiceName     CostUSD  Percentage from the Average Cost
# 23  2022-12-01        Azure Apps  669.600000                        102.542113
# 24  2022-12-01  Azure Kubernetes   74.387951                        100.524258
# 29  2022-12-01     Log Analytics  123.887243                        103.239369
# 31  2022-12-01           Storage  958.386417                        100.882781
# 34  2023-01-01        Azure Apps  668.300000                        102.343032
# 35  2023-01-01  Azure Kubernetes   74.402057                        100.543321
# 40  2023-01-01     Log Analytics  123.196257                        102.663547
# 42  2023-01-01           Storage  993.933550                        104.624584
# 45  2023-02-01        Azure Apps  604.800000                         92.618683
# 46  2023-02-01  Azure Kubernetes   67.204555                         90.816966
# 51  2023-02-01     Log Analytics  110.500601                         92.083834
# 53  2023-02-01           Storage  925.939338                         97.467299
# 56  2023-03-01        Azure Apps  669.600000                        102.542113
# 57  2023-03-01  Azure Kubernetes   82.876639                        111.995458
# 62  2023-03-01     Log Analytics  123.234606                        102.695505
# 64  2023-03-01           Storage  924.620123                         97.328434
# 65  2023-03-01  Virtual Machines  280.827883                        401.182690
